# %% [markdown]
# Project Description:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an
# algorithm that predicts the number of wins for a given team in the 2015
# season based on several different indicators of success.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
'''IMPORTING THE LIBRARIES
EPLORATORY DATA ANALYSIS
do non graphical analysis
ghraphical analysis
    univariate analysis
    bivariate analysis
    multivaraiate analysis
check outliers and remove if present
check multicollinearity
remove multicollinearity if present
apply feature scaling methods on numerical features
apply resampling methods to balance the classes
split the dataset into features and target variable and then train data and test dataset by using train_test_split() method
Model Building
Cross Validation Score
Finalizing the Model
Predicting the saved Model'''
# Out:
# 'IMPORTING THE LIBRARIES\nEPLORATORY DATA ANALYSIS\ndo non graphical analysis\nghraphical analysis\n    univariate analysis\n    bivariate analysis\n    multivaraiate analysis\ncheck outliers and remove if present\ncheck multicollinearity\nremove multicollinearity if present\napply feature scaling methods on numerical features\napply resampling methods to balance the classes\nsplit the dataset into features and target variable and then train data and test dataset by using train_test_split() method\nModel Building\nCross Validation Score\nFinalizing the Model\nPredicting the saved Model'

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Observation :
# This Baseball Dataset contains 30 rows & 17 columns.
# Here our objective is to predict Wins using classification algorithim for that Here our target variable is 'W'.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# So we have 16 int64 dtypes and 1 float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#Missing Value check
plt.figure(figsize = (8,6))
sns.heatmap(df.isnull(),cmap = 'cool_r')
plt.show()

# %% [markdown]
# there is no null value in the dataset.

# %%
# checking the value counts of each column
for i in df.columns:
    print (df[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
#descriptive Analysis
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observations:-
# 1.Mean is minimally on a higher side than 50% in At Bat, Hit,Home runs,save,Errors. Here it is positive skewed data.
# 2.Mean is less than 50% IN Wins, runs,2nd base,base on Balls, Strikeout,Run average,Earned Run,Earned run Averages,Shutout. Here it is negatively or left skewed data.
# 3.There is a significatly noticeable difference between 75%(Qusrtile 3) and Max. So all the variables have outliers present in them. We will have to treat skewness and outliers as well.

# %% [markdown]
# # Data Visualization and Interpretation

# %%
#Univariate Analysis
ch = sns.countplot(x='W',data=df)
print (df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# So its been 3 times that the pitcher was credited with 68 number of wins. followed by 74,76,81,83 which ws credited 2 times.

# %%
sns.histplot(x=df.W, ec = "black", color='g', kde=True)
# Out:
# <Axes: xlabel='W', ylabel='Count'>

# %% [markdown]
# We observe that the max of the rows lie in range 80-85 and overall the data is very uniform , no outliers on either side.

# %%
#Finding distribution of dat in each column
plt.figure(figsize =(30,50), facecolor = 'green')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(9,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 30)
        plt.yticks(rotation=0,fontsize=30)       
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# 1.We observe that Runs,Hit,HomeRuns,StolenBase,CompleteGame,Error seems to be postively skewed data. which we will have to treat. 2. rest of the data seems to bee equally distributed.  3. As very less data is available accurate predictions may not be possible.

# %% [markdown]
# # Finding Correlation

# %%
cor=df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Finding correlation of features wirh the target variables
cor["W"].sort_values(ascending=True)
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# Findings:-1)Earned Runs, Earned Runs Average and Run average are highly correlated to each other.2. They are moderately corrrelated to SV and SHO.3.H and AB also seems to have high correlation of 0.74 between them. here due to multicollinearity issue we will have to remove ER,RA and H as their molticollinearity is on a higher sside.

# %%
#visualizing correlation between Features and Target by bar plot
df.corr()["W"].sort_values(ascending=False).drop(["W"]).plot(kind='bar',color="m")
plt.xlabel("feature",fontsize=15)
plt.ylabel("target",fontsize=15)
plt.title("Correlation between label andd features using Barplot", fontsize=20)
plt.show()

# %%
#Bivariate Analysis
sns.barplot(x='W', y='R', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='R'>

# %%
sns.barplot(x='W', y='AB', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='AB'>

# %%
sns.barplot(x='W', y='H', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='H'>

# %%
sns.barplot(x='W', y='2B', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='2B'>

# %%
sns.barplot(x='W', y='3B', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='3B'>

# %%
sns.barplot(x='W', y='HR', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='HR'>

# %%
sns.barplot(x='W', y='BB', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='BB'>

# %%
sns.barplot(x='W', y='SO', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='SO'>

# %%
sns.barplot(x='W', y='SB', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='SB'>

# %%
sns.barplot(x='W', y='RA', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='RA'>

# %%
sns.barplot(x='W', y='ER', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='ER'>

# %%
sns.barplot(x='W', y='ERA', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='ERA'>

# %%
sns.barplot(x='W', y='CG', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='CG'>

# %%
sns.barplot(x='W', y='SHO', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='SHO'>

# %%
sns.barplot(x='W', y='SV', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='SV'>

# %%
sns.barplot(x='W', y='E', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <Axes: xlabel='W', ylabel='E'>

# %%
#Multicollinearity Analysis
sns.pairplot(df,palette="Dark2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# So as ER,RA,ERA are highley negatively correlated to the tagrte varible ,its better to drop ER,RA and AB columns

# %%
df.drop(columns = ['ER','RA','AB'], inplace=True)

# %%
df
# Out:
#       W    R     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 5    93  891  1480  308  17  232  570  1151   88  3.80   7   10  34   88
# 6    87  764  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# 11   86  729  1363  278  26  230  486  1392  121  3.57   5   13  39   85
# ...

# %% [markdown]
# # Finding Outliers

# %%
#checking outliers by Boxplot
plt.figure(figsize =(30,50), facecolor="white")
plotnumber= 1
for column in df:
    if plotnumber<=14:
        ax = plt.subplot (7,2,plotnumber)
        sns.boxplot (df[column],palette='Set2_r')
        plt.xlabel(column,fontsize= 20 )
        plt.yticks(rotation=0,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# R,ERA,SV, SHA and E has outliers availbale in the data.

# %%
#Treating outliers with Z-score method
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       W    R     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 6    87  764  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# 11   86  729  1363  278  26  230  486  1392  121  3.57   5   13  39   85
# 12   85  661  1331  243  21  176  435  1150   52  3.94   2   12  46   93
# ...

# %%
#Treating Outliers with IQR METHOD
from scipy import stats
IQR = stats.iqr(df)
IQR
# Out:
# 442.25

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# %%
df2 = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df2
# Out:
#       W    R     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 5    93  891  1480  308  17  232  570  1151   88  3.80   7   10  34   88
# 6    87  764  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# 11   86  729  1363  278  26  230  486  1392  121  3.57   5   13  39   85
# ...

# %% [markdown]
# In both the outliers removal method we see data loss in Z-score method. And as very less data is available we can take Z-score method.

# %% [markdown]
# # Separating Features and Label/target variables

# %%
x=df1.drop("W",axis=1)
y=df1["W"]

# %% [markdown]
# # Treating Skewness

# %%
x.skew()
# Out:
# R     -0.215364
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.671748
# dtype: float64

# %% [markdown]
# we see that skewness has minimally decreased.

# %% [markdown]
# # Feature Scaling using Min-Max Scaling (Normalization)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
X= mms.fit_transform(x)
X.shape
# Out:
# (29, 13)

# %%
X
# Out:
# array([[0.79057592, 0.90575916, 0.95522388, 0.80555556, 0.3       ,
#         0.04166667, 0.        , 0.66666667, 0.37619048, 0.18181818,
#         0.23529412, 0.82352941, 0.28989677],
#        [0.64397906, 0.13089005, 0.6119403 , 0.86111111, 0.43076923,
#         0.33333333, 0.53394495, 0.28888889, 0.53809524, 0.18181818,
#         0.47058824, 0.5       , 0.24724668],
#        [0.5026178 , 0.37172775, 1.        , 0.44444444, 0.31538462,
#         0.82291667, 0.33761468, 0.46666667, 0.34761905, 1.        ,
#         0.35294118, 0.29411765, 0.09254352],
#        [0.2565445 , 0.29842932, 0.35820896, 0.38888889, 0.27692308,
#         0.15104167, 0.4733945 , 0.26666667, 0.4952381 , 0.63636364,
#         0.29411765, 0.26470588, 0.55247715],
#        [0.60732984, 1.        , 0.79104478, 1.        , 0.39230769,
#         0.41666667, 0.52477064, 0.43333333, 0.80952381, 0.63636364,
#         0.47058824, 0.20588235, 0.24724668],
# ...

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# # Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
v=variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[v(X,i) for i in range(X.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values Features
# 0    41.371559        R
# 1    11.143134        H
# 2    17.730518       2B
# 3    14.123230       3B
# 4    31.302738       HR
# 5    11.119287       BB
# 6    17.769168       SO
# 7     6.418670       SB
# 8    10.659471      ERA
# 9     5.344543       CG
# 10    8.846979      SHO
# 11    7.778240       SV
# 12    4.858667        E

# %%
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()
X_scaler = scalar.fit_transform(X)
X_scaler.shape
# Out:
# (29, 13)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
v=variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[v(X_scaler,i) for i in range(X_scaler.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values Features
# 0     6.152516        R
# 1     4.043785        H
# 2     3.122410       2B
# 3     3.234008       3B
# 4     5.763910       HR
# 5     2.910598       BB
# 6     2.121011       SO
# 7     1.824031       SB
# 8     4.919101      ERA
# 9     2.132078       CG
# 10    3.188540      SHO
# 11    2.705823       SV
# 12    1.480310        E

# %% [markdown]
# Hense taking X_scaler vales further for Model developement. All vif values are less than 10 heense no multicollinearity exists.

# %% [markdown]
# # Modelling or Model Buildingn and Cross_valuation Score

# %%
#Importing Libraries
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
maxAccu=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(X_scaler,y,test_size=.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum r2 score is',maxAccu,'on Random_state',maxRS)
# Out:
# Maximum r2 score is 0.978431318007174 on Random_state 47

# %%
 x_train,x_test,y_train,y_test = train_test_split(X_scaler,y,test_size=.20, random_state=47)

# %%
print('Size of x_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of x_test : ', x_test.shape)
print('Size of y_test : ', y_test.shape)
# Out:
# Size of x_train :  (23, 13)
# Size of y_train :  (23,)
# Size of x_test :  (6, 13)
# Size of y_test :  (6,)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_LR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_LR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_LR)))
score = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross validation score is =', (r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# R2_score: 0.978431318007174
# R2_score on training Data: 92.60799478038614
# Mean Absolute Error:- 1.39335720435682
# Mean Squared Error:- 2.722446971538925
# Root Mean Squared Error:- 1.649983930691122
# [ 0.6003841  -1.04736662  0.63473455  0.68626636  0.81361821]
# 0.33752731830140265
# Difference between R2 score and cross validation score is = 64.09039997057712

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted', fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_RFR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_RFR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_RFR)))
score1 = cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# R2_score: 0.703671698943662
# R2_score on training Data: 93.4455731782706
# Mean Absolute Error:- 5.3450000000000015
# Mean Squared Error:- 37.403216666666665
# Root Mean Squared Error:- 6.115816925535514
# [ 0.20411875 -5.40817237  0.44817934  0.38192066  0.83300059]
# -0.7081906067744163
# Difference between R2 score and cross validation score is –  141.1862305718078

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_knn))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_knn))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_knn)))
score2 = cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print('Difference between R2 score and cross validation score is =', (r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# R2_score: 0.6079401408450704
# R2_score on training Data: 61.10563325863533
# Mean Absolute Error:- 5.766666666666666
# Mean Squared Error:- 49.48666666666667
# Root Mean Squared Error:- 7.034676017178522
# [-0.8165     -1.15263158 -0.04990381 -0.24504918 -0.06639151]
# -0.46609521492962785
# Difference between R2 score and cross validation score is = 107.40353557746982

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_GBR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_GBR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_GBR)))
score3 = cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print('Difference between R2 score and cross validation score is –', (r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# R2_score: 0.7777504421817059
# R2_score on training Data: 99.99999265770569
# Mean Absolute Error:- 4.468101949661232
# Mean Squared Error:- 28.052833075731353
# Root Mean Squared Error:- 5.296492525788302
# [ 0.0903097  -9.3260222   0.50428674  0.53941191  0.8535489 ]
# -1.467692991622394
# Difference between R2 score and cross validation score is – 224.54434338041

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_lasso))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_lasso))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_lasso)))
score4 = cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# R2_score: 0.9210988950159694
# R2_score on training Data: 86.26274286618431
# Mean Absolute Error:- 2.547055590182834
# Mean Squared Error:- 9.95907280687319
# Root Mean Squared Error:- 3.1557998680006927
# [-0.16524858 -2.0868738   0.40994079  0.70426008  0.79460676]
# -0.06866294789564589
# Difference between R2 score and cross validation score is –  98.97618429116153

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_rd))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_rd))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_rd)))
score5 = cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_rd) - score5.mean())*100)
# Out:
# R2_score: 0.941413570848948
# R2_score on training Data: 91.7654733982834
# Mean Absolute Error:- 2.5775489103777525
# Mean Squared Error:- 7.394909279510564
# Root Mean Squared Error:- 2.719358247732462
# [ 0.0199725  -1.28339412  0.61382008  0.87874935  0.79852489]
# 0.2055345397635758
# Difference between R2 score and cross validation score is –  73.5879031085372

# %%
dt= DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
pred_train=dt.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dt))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_dt))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_dt))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_dt)))
score6 = cross_val_score(dt,x,y)
print(score6)
print(score6.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_dt) - score6.mean())*100)
# Out:
# R2_score: 0.6830985915492958
# R2_score on training Data: 100.0
# Mean Absolute Error:- 5.666666666666667
# Mean Squared Error:- 40.0
# Root Mean Squared Error:- 6.324555320336759
# [ -0.80340909 -12.86842105   0.35173568   0.86885246  -0.22936321]
# -2.5361210433243686
# Difference between R2 score and cross validation score is –  321.92196348736644

# %%
svr= SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_svr))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_svr))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_svr))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_svr)))
score7 = cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_svr) - score7.mean())*100)
# Out:
# R2_score: 0.08624868141131936
# R2_score on training Data: 21.658991310788146
# Mean Absolute Error:- 9.018074824661435
# Mean Squared Error:- 115.33572199074904
# Root Mean Squared Error:- 10.739447005816874
# [-0.1587198  -1.26749967 -0.06469282 -0.63987019 -0.03558501]
# -0.43327349724249303
# Difference between R2 score and cross validation score is –  51.95221786538124

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_etr))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_etr))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_etr))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_etr)))
score8 = cross_val_score(etr,x,y)
print(score8)
print(score8.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_etr) - score8.mean())*100)
# Out:
# R2_score: 0.7148822183098591
# R2_score on training Data: 100.0
# Mean Absolute Error:- 4.6333333333333355
# Mean Squared Error:- 35.9882
# Root Mean Squared Error:- 5.999016586074754
# [ 0.094      -3.81133816  0.56134412  0.46013721  0.78136557]
# -0.38289825098893526
# Difference between R2 score and cross validation score is –  109.77804692987942

# %%
model = [('Linear Regression', r2_score(y_test,pred_LR),np.sqrt(mean_squared_error(y_test, pred_LR)),score.mean()),
          ('Random Forest Regressor',r2_score(y_test,pred_RFR),np.sqrt(mean_squared_error(y_test, pred_RFR)),score1.mean()),
          ('KNN',r2_score(y_test,pred_knn),np.sqrt(mean_squared_error(y_test, pred_knn)),score2.mean()),
          ('GradientBoostingRegressor',r2_score(y_test,pred_GBR),np.sqrt(mean_squared_error(y_test, pred_GBR)),score3.mean()),
         ('Lasso',r2_score(y_test,pred_lasso),np.sqrt(mean_squared_error(y_test, pred_lasso)),score4.mean()),
         ('Ridge',r2_score(y_test,pred_rd),np.sqrt(mean_squared_error(y_test, pred_rd)),score5.mean()),
         ('DecisionTreeRegressor',r2_score(y_test,pred_dt),np.sqrt(mean_squared_error(y_test, pred_dt)),score6.mean()),
         ('SVR',r2_score(y_test,pred_svr),np.sqrt(mean_squared_error(y_test, pred_svr)),score7.mean()),
         ('ExtraTreesRegressor',r2_score(y_test,pred_etr),np.sqrt(mean_squared_error(y_test, pred_etr)),score8.mean())
        ]

# %%
Model = pd.DataFrame(data = model, columns=['Model','R2_Score(test)','RMSE', 'Cross-Validation'])
Model
# Out:
#                        Model  R2_Score(test)       RMSE  Cross-Validation
# 0          Linear Regression        0.978431   1.649984          0.337527
# 1    Random Forest Regressor        0.703672   6.115817         -0.708191
# 2                        KNN        0.607940   7.034676         -0.466095
# 3  GradientBoostingRegressor        0.777750   5.296493         -1.467693
# 4                      Lasso        0.921099   3.155800         -0.068663
# 5                      Ridge        0.941414   2.719358          0.205535
# 6      DecisionTreeRegressor        0.683099   6.324555         -2.536121
# 7                        SVR        0.086249  10.739447         -0.433273
# 8        ExtraTreesRegressor        0.714882   5.999017         -0.382898

# %% [markdown]
# From the above observation , it can be concluded that Linear Reg is the best Model having r2_score as 0.97 and CV as .33 so the difference is 64.09.

# %% [markdown]
# # Model Fitting

# %%
#As Linear Regression does not have paramenters. hense dfinalling the model and Model fitting

# %%
Final_model=LinearRegression()
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
pred
# Out:
# array([97.83539684, 75.55262716, 73.88751389, 83.62498887, 77.14058142,
#        61.87991143])

# %% [markdown]
# # Saving the Model

# %%
#saving the model using .pkl
import joblib
joblib.dump(Final_model,"BaseBall_casestudy_Prediction.pkl")
# Out:
# ['BaseBall_casestudy_Prediction.pkl']

# %% [markdown]
# # Make Predictions on Test Data:

# %%
#lets load the saved model and get the predictions
model=joblib.load('BaseBall_casestudy_Prediction.pkl')
result=model.score(x_test,y_test)

# %%
print(result*100)
# Out:
# 97.8431318007174

# %%
conclusion=pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                     0          1          2          3          4          5
# Predicted   97.835397  75.552627  73.887514  83.624989  77.140581  61.879911
# Original   100.000000  76.000000  74.000000  86.000000  76.000000  64.000000
